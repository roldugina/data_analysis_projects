# %% [markdown]
# <a href="https://colab.research.google.com/github/roldugina/data_analysis_projects/blob/main/FreeCodeCamp4_dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
print(pd.__version__)
# Out:
# 1.5.3

# %%
pd.DataFrame(data=[None],index=[None],columns=[None])
# Out:
#       None
# None  None

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
marvel_df=pd.DataFrame(marvel_data)

# %%
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
col_names = ['name', 'sex', 'first_appearance']
marvel_df.columns=col_names

# %%
marvel_df.index=marvel_df['name']
marvel_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
marvel_df=marvel_df.drop(['name'],axis=1)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df=marvel_df.drop('Spider-Man',axis=0)

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963
# Thing            male              1961

# %%
marvel_df.tail()
# Out:
#                   sex  first_appearance
# name
# Hank Pym         male              1962
# Scarlet Witch  female              1964
# Wasp           female              1963
# Black Widow    female              1964
# Vision           male              1968

# %%
marvel_df.iloc[:5]
# Out:
#                   sex  first_appearance
# name
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963
# Thing            male              1961

# %%
marvel_df.iloc[-5:]
# Out:
#                   sex  first_appearance
# name
# Hank Pym         male              1962
# Scarlet Witch  female              1964
# Wasp           female              1963
# Black Widow    female              1964
# Vision           male              1968

# %%
marvel_df.describe()
# Out:
#        first_appearance
# count         19.000000
# mean        1961.842105
# std            8.636249
# min         1939.000000
# 25%         1961.500000
# 50%         1963.000000
# 75%         1964.000000
# max         1975.000000

# %%
marvel_df['sex'].head()
# Out:
# name
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Thing              male
# Name: sex, dtype: object

# %%
marvel_df['first_appearance'].tail()
# Out:
# name
# Hank Pym         1962
# Scarlet Witch    1964
# Wasp             1963
# Black Widow      1964
# Vision           1968
# Name: first_appearance, dtype: int64

# %%
marvel_df['sex'].to_frame()
# Out:
#                      sex
# name
# Captain America     male
# Wolverine           male
# Iron Man            male
# Thor                male
# Thing               male
# Mister Fantastic    male
# Hulk                male
# Beast               male
# Invisible Woman   female
# Storm             female
# Namor               male
# Hawkeye             male
# Daredevil           male
# Doctor Strange      male
# Hank Pym            male
# Scarlet Witch     female
# Wasp              female
# Black Widow       female
# Vision              male

# %%
marvel_df.iloc[-5:]
# Out:
#                   sex  first_appearance
# name
# Hank Pym         male              1962
# Scarlet Witch  female              1964
# Wasp           female              1963
# Black Widow    female              1964
# Vision           male              1968

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df.iloc[1:-1].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Namor                         1939
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Hank Pym                      1962
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.iloc[[0,-1]]
# Out:
#                   sex  first_appearance
# name
# Captain America  male              1941
# Vision           male              1968

# %%
marvel_df.loc['Wasp','first_appearance']=1941

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1941
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df['Years_since']=datetime.now().year-marvel_df['first_appearance']
marvel_df
# Out:
#                      sex  first_appearance  Years_since
# name
# Captain America     male              1941           82
# Wolverine           male              1974           49
# Iron Man            male              1963           60
# Thor                male              1963           60
# Thing               male              1961           62
# Mister Fantastic    male              1961           62
# Hulk                male              1962           61
# Beast               male              1963           60
# Invisible Woman   female              1961           62
# Storm             female              1975           48
# Namor               male              1939           84
# Hawkeye             male              1964           59
# Daredevil           male              1964           59
# Doctor Strange      male              1963           60
# Hank Pym            male              1962           61
# Scarlet Witch     female              1964           59
# ...

# %%
mask=marvel_df['sex']=='female'
mask
# Out:
# name
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
marvel_df[mask]
# Out:
#                     sex  first_appearance  Years_since
# name
# Invisible Woman  female              1961           62
# Storm            female              1975           48
# Scarlet Witch    female              1964           59
# Wasp             female              1941           82
# Black Widow      female              1964           59

# %%
marvel_df
# Out:
#                      sex  first_appearance  Years_since
# name
# Captain America     male              1941           82
# Wolverine           male              1974           49
# Iron Man            male              1963           60
# Thor                male              1963           60
# Thing               male              1961           62
# Mister Fantastic    male              1961           62
# Hulk                male              1962           61
# Beast               male              1963           60
# Invisible Woman   female              1961           62
# Storm             female              1975           48
# Namor               male              1939           84
# Hawkeye             male              1964           59
# Daredevil           male              1964           59
# Doctor Strange      male              1963           60
# Hank Pym            male              1962           61
# Scarlet Witch     female              1964           59
# ...

# %%
mask=marvel_df['first_appearance']>1960
mask
# Out:
# name
# Captain America     False
# Wolverine            True
# Iron Man             True
# Thor                 True
# Thing                True
# Mister Fantastic     True
# Hulk                 True
# Beast                True
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye              True
# Daredevil            True
# Doctor Strange       True
# Hank Pym             True
# Scarlet Witch        True
# Wasp                False
# Black Widow          True
# Vision               True
# Name: first_appearance, dtype: bool

# %%
marvel_df.loc[marvel_df['first_appearance']>1960]
# Out:
#                      sex  first_appearance  Years_since
# name
# Wolverine           male              1974           49
# Iron Man            male              1963           60
# Thor                male              1963           60
# Thing               male              1961           62
# Mister Fantastic    male              1961           62
# Hulk                male              1962           61
# Beast               male              1963           60
# Invisible Woman   female              1961           62
# Storm             female              1975           48
# Hawkeye             male              1964           59
# Daredevil           male              1964           59
# Doctor Strange      male              1963           60
# Hank Pym            male              1962           61
# Scarlet Witch     female              1964           59
# Black Widow       female              1964           59
# Vision              male              1968           55

# %%
mask2=marvel_df['sex']=='male'

# %%
marvel_df.loc[mask2]
# Out:
#                    sex  first_appearance  Years_since
# name
# Captain America   male              1941           82
# Wolverine         male              1974           49
# Iron Man          male              1963           60
# Thor              male              1963           60
# Thing             male              1961           62
# Mister Fantastic  male              1961           62
# Hulk              male              1962           61
# Beast             male              1963           60
# Namor             male              1939           84
# Hawkeye           male              1964           59
# Daredevil         male              1964           59
# Doctor Strange    male              1963           60
# Hank Pym          male              1962           61
# Vision            male              1968           55

# %%
mask3=(marvel_df['sex']=='female')&(marvel_df['first_appearance']>1970)
mask3
marvel_df.loc[mask3]
# Out:
#           sex  first_appearance  Years_since
# name
# Storm  female              1975           48

# %%
marvel_df['first_appearance'].mean()
# Out:
# 1960.6842105263158

# %%
marvel_df['first_appearance'].min()
# Out:
# 1939

# %%
marvel_df.first_appearance.min()
# Out:
# 1939

# %%
mask=marvel_df.first_appearance==marvel_df.first_appearance.min()
marvel_df.loc[mask]
# Out:
#         sex  first_appearance  Years_since
# name
# Namor  male              1939           84

# %%
marvel_df = marvel_df.reset_index()
marvel_df
# Out:
#                 name     sex  first_appearance
# 0    Captain America    male              1941
# 1          Wolverine    male              1974
# 2           Iron Man    male              1963
# 3               Thor    male              1963
# 4              Thing    male              1961
# 5   Mister Fantastic    male              1961
# 6               Hulk    male              1962
# 7              Beast    male              1963
# 8    Invisible Woman  female              1961
# 9              Storm  female              1975
# 10             Namor    male              1939
# 11           Hawkeye    male              1964
# 12         Daredevil    male              1964
# 13    Doctor Strange    male              1963
# 14          Hank Pym    male              1962
# 15     Scarlet Witch  female              1964
# 16              Wasp  female              1963
# 17       Black Widow  female              1964
# 18            Vision    male              1968

# %%
marvel_df.first_appearance.plot()
# Out:
# <Axes: >

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 14.,  0.,  1.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

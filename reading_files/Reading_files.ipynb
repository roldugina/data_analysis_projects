# %% [markdown]
# <a href="https://colab.research.google.com/github/roldugina/data_analysis_projects/blob/main/reading_files/Reading_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Reading CSV files

# %%
filepath='https://raw.githubusercontent.com/krishnatray/RDP-Reading-Data-with-Python-and-Pandas/master/unit-1-reading-data-with-python-and-pandas/lesson-1-reading-csv-and-txt-files/files/btc-market-price.csv'

# %%
df=pd.read_csv(filepath,names=['Date','Price'],dayfirst=True,na_values=['', '?', '-'],parse_dates=[0],index_col=[0],skiprows=[1,2])
df.head()
# Out:
#                   Price
# Date
# 2017-04-02  1099.169125
# 2017-04-05  1133.079314
# 2017-04-06          NaN
# 2017-04-07          NaN
# 2017-04-08  1181.149838

# %%
filepath2='https://raw.githubusercontent.com/krishnatray/RDP-Reading-Data-with-Python-and-Pandas/master/unit-1-reading-data-with-python-and-pandas/lesson-1-reading-csv-and-txt-files/files/exam_review.csv'

# %%
df2=pd.read_csv(filepath2,na_values=['', '?', '-'],sep='>',decimal=',')
df2.head()
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.to_csv('out.csv')

# %% [markdown]
# ## Reading files by pure Python

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/datasets'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/datasets

# %%
filepath='btc-market-price.csv'

# %%
with open(filepath,'a') as reader:
  reader.write('\neuhetonuh')
  reader.close()

reader=open(filepath,'r')
print(reader)
for index,line in enumerate(reader.readlines()):
  print(index,line)
reader.close()

# %% [markdown]
# ## Reading Excel files

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/datasets'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/datasets

# %%
# %ls
# Out:
# btc-market-price.csv  out.csv  out_products_merchants.xlsx  products.xlsx  pr.xlsx

# %%
filepath3='products.xlsx'
filepath4='https://github.com/roldugina/data_analysis_projects/blob/ab094746e60c84bdd8c83e2d7b2e2a51e1327566/reading_files/products2.xlsx'

# %%
ex=pd.read_excel(filepath3,engine='openpyxl',index_col=0,na_values=['', '?', '-'],sheet_name='Merchants')
ex.head()
# Out:
#                      merchant
# merchant_id
# 1001              Bestbuy.com
# 1002              Walmart.com
# 1003              Bestbuy.com
# 1004                 Growkart
# 1005         bhphotovideo.com

# %%
ex_file=pd.ExcelFile(filepath3,engine='openpyxl')

# %%
ex_products=ex_file.parse(ex_file.sheet_names[0])
ex_merchants=ex_file.parse(ex_file.sheet_names[2])

# %%
ex_file.sheet_names
# Out:
# ['Products', 'Descriptions', 'Merchants']

# %%
ex_products.to_excel('pr.xlsx',sheet_name='pr')
ex_file2=pd.ExcelFile('pr.xlsx',engine='openpyxl')
ex_df2=ex_file2.parse(ex_file2.sheet_names[0])
ex_df2
# Out:
#       Unnamed: 0            product_id   price  merchant_id      brand  \
# 0              0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1              1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2              2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3              3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4              4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...          ...                   ...     ...          ...        ...
# 1240        1240  AVphFybdLJeJML43Wnza   64.95         1110        JBL
# 1241        1241  AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# 1242        1242  AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# 1243        1243  AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# 1244        1244  AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                    name
# 0     Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# ...

# %%
ex_file2.sheet_names
# Out:
# ['pr']

# %%
with pd.ExcelWriter('out_products_merchants.xlsx') as writer:
  ex_products.to_excel(writer,sheet_name='Products')
  ex_merchants.to_excel(writer,sheet_name='Merchants')

# %%
ex_file3=pd.ExcelFile('out_products_merchants.xlsx')
ex_file3.sheet_names
# Out:
# ['Products', 'Merchants']
